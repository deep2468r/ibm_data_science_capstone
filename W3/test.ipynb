# %%
import pandas as pd

# %%
df = pd.read_csv('spacex_launch_dash.csv', index_col=False)
df.head()
# Out:
#    Unnamed: 0  Flight Number  Launch Site  class  Payload Mass (kg)  \
# 0           0              1  CCAFS LC-40      0                0.0
# 1           1              2  CCAFS LC-40      0                0.0
# 2           2              3  CCAFS LC-40      0              525.0
# 3           3              4  CCAFS LC-40      0              500.0
# 4           4              5  CCAFS LC-40      0              677.0
#
#   Booster Version Booster Version Category
# 0  F9 v1.0  B0003                     v1.0
# 1  F9 v1.0  B0004                     v1.0
# 2  F9 v1.0  B0005                     v1.0
# 3  F9 v1.0  B0006                     v1.0
# 4  F9 v1.0  B0007                     v1.0

# %%
df[df['Launch Site'] == 'CCAFS LC-40']
# Out:
#     Unnamed: 0  Flight Number  Launch Site  class  Payload Mass (kg)  \
# 0            0              1  CCAFS LC-40      0                0.0
# 1            1              2  CCAFS LC-40      0                0.0
# 2            2              3  CCAFS LC-40      0              525.0
# 3            3              4  CCAFS LC-40      0              500.0
# 4            4              5  CCAFS LC-40      0              677.0
# 5            5              7  CCAFS LC-40      0             3170.0
# 6            6              8  CCAFS LC-40      0             3325.0
# 7            7              9  CCAFS LC-40      0             2296.0
# 8            8             10  CCAFS LC-40      0             1316.0
# 9            9             11  CCAFS LC-40      0             4535.0
# 10          10             12  CCAFS LC-40      0             4428.0
# 11          11             13  CCAFS LC-40      0             2216.0
# 12          12             14  CCAFS LC-40      0             2395.0
# ...

# %%
launch_sites = df['Launch Site'].unique()

# %%
launch_sites.tolist()
# Out:
# ['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40']

# %%
site_options = [{'label': "All sites", 'value': 'ALL'}]

for site in launch_sites:
    site_options.append({'label': site, 'value': site})

site_options
# Out:
# [{'label': 'All sites', 'value': 'ALL'},
#  {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
#  {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
#  {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
#  {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}]

# %%
df.head()
# Out:
#    Unnamed: 0  Flight Number  Launch Site  class  Payload Mass (kg)  \
# 0           0              1  CCAFS LC-40      0                0.0
# 1           1              2  CCAFS LC-40      0                0.0
# 2           2              3  CCAFS LC-40      0              525.0
# 3           3              4  CCAFS LC-40      0              500.0
# 4           4              5  CCAFS LC-40      0              677.0
#
#   Booster Version Booster Version Category
# 0  F9 v1.0  B0003                     v1.0
# 1  F9 v1.0  B0004                     v1.0
# 2  F9 v1.0  B0005                     v1.0
# 3  F9 v1.0  B0006                     v1.0
# 4  F9 v1.0  B0007                     v1.0

# %%
import plotly.express as px

# %%
df.groupby(['class'])['class'].count().values.tolist()
# Out:
# [32, 24]

# %%
px.pie(names=df['class'].unique().tolist(), values=df.groupby('class').count())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/0y/2kmlwh2x6_x71q7m616mf00w0000gn/T/ipykernel_13790/681810566.py in ?()
# ----> 1 px.pie(names=df['class'].unique().tolist(), values=df.groupby('class').count())
#
# ~/anaconda3/lib/python3.11/site-packages/plotly/express/_chart_types.py in ?(data_frame, names, values, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, category_orders, labels, title, template, width, height, opacity, hole)
#    1478     if color_discrete_sequence is not None:
#    1479         layout_patch = {"piecolorway": color_discrete_sequence}
#    1480     else:
#    1481         layout_patch = {}
# -> 1482     return make_figure(
#    1483         args=locals(),
#    1484         constructor=go.Pie,
# ...
